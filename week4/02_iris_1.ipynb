# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyairi8/tomoshibi-AIseminar/blob/main/02_iris_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_openml
iris = fetch_openml(name="iris", version=1, as_frame=True)
iris_df = iris.frame
iris_df
import seaborn as sns

#ここに入力
sns.lmplot(data = iris_df, x = "sepallength", y = "petallength", hue = "class")
